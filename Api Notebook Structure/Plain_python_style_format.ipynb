# %% [markdown]
# <a href="https://colab.research.google.com/github/Love1117/Machine_learning-Projects/blob/main/Api%20Notebook%20Structure/Plain_python_style_format.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Love1117/Machine_learning-Projects.git
# Out:
# fatal: destination path 'Machine_learning-Projects' already exists and is not an empty directory.

# %%
# %cd /content/Machine_learning-Projects
# %cd "Machine_Learning Project/01_Supervised- Machine Learning/01_Linear_Regression/Car_price_prediction"
# Out:
# /content/Machine_learning-Projects
# /content/Machine_learning-Projects/Machine_Learning Project/01_Supervised- Machine Learning/01_Linear_Regression/Car_price_prediction

# %%
# %%writefile app.py
from fastapi import FastAPI
import uvicorn

app = FastAPI()

@app.get("/")
def home():
  return {"message": "FastAPI API created in Colab"}
# Out:
# Writing app.py

# %%
# !ls
# Out:
#  app.py			       Machine_learning-Projects  'Model Versions'
#  Car_price_prediction1.ipynb   main.py			   README.md
# 'images (3).jpeg'	       Models

# %%
# !git add app.py
# !git status
# !git commit -m "Add FastAPI Car Price Prediction API"
# Out:
# On branch main
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   app.py
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Machine_learning-Projects/
#
# [main 8f27cdd] Add FastAPI Car Price Prediction API
#  1 file changed, 8 insertions(+)
#  create mode 100644 Machine_Learning Project/01_Supervised- Machine Learning/01_Linear_Regression/Car_price_prediction/app.py

# %%
# !git config --global user.name "Loveday Shadrack"
# !git config --global user.email "lovedayshadrack@gmail.com"

# %%
# !git push https://Love1117:GH_PATH@github.com/Love1117/Machine_learning-Projects.git
# Out:
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 508 bytes | 508.00 KiB/s, done.
# Total 6 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To https://github.com/Love1117/Machine_learning-Projects.git
#    9d8ce74..8f27cdd  main -> main
